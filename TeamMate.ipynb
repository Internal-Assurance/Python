# %%
# Navegando no TeamMate
import pyautogui
import time

# Alerta de início:
pyautogui.alert("O código vai iniciar. Gentileza não utilizar nada enquanto ele estiver rodando!")
pyautogui.PAUSE = 1.0

# Abrir o TEAMS no computador:
pyautogui.press('winleft')
pyautogui.write('internet')
pyautogui.press('enter')
time.sleep(10)
pyautogui.moveTo(87, 92)
time.sleep(2)
pyautogui.click()
time.sleep(4)
time.sleep(2)
pyautogui.write('inserir sua senha')
time.sleep(2)
pyautogui.press('enter')
time.sleep(10)
pyautogui.press('enter')

# Selecionando exibição:
pyautogui.moveTo(1329, 190)
pyautogui.click()
time.sleep(2)
pyautogui.moveTo(1287, 332)
pyautogui.click()
pyautogui.moveTo(1285, 368)
pyautogui.click()
pyautogui.moveTo(1286, 402)
pyautogui.click()
pyautogui.moveTo(1287, 435)
pyautogui.click()

pyautogui.moveTo(1327, 184)
pyautogui.click()
time.sleep(8)

pyautogui.moveTo(1348, 184)
pyautogui.click()
pyautogui.moveTo(1346, 147)
pyautogui.click()
pyautogui.scroll(-200)
time.sleep(2)
pyautogui.click()
pyautogui.press('pgdn')

# Remover e logout
pyautogui.press('pgup')
pyautogui.moveTo(1306, 229)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1253, 338)
pyautogui.click()

pyautogui.moveTo(1306, 229)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1253, 338)
pyautogui.click()

pyautogui.moveTo(1324, 229)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1275, 337)
pyautogui.click()
time.sleep(2)

pyautogui.moveTo(698, 231)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(656, 336)
pyautogui.click()
time.sleep(2)

pyautogui.moveTo(1311, 115)
pyautogui.click()
time.sleep(1)
pyautogui.moveTo(1168, 254)
pyautogui.click()
time.sleep(10)

# Fechando explorer
pyautogui.moveTo(1342, 5)
pyautogui.click()

# End

# %% [markdown]
# #### pyautogui.position()
